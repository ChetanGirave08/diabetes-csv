# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanGirave08/diabetes-csv/blob/main/diabetes_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

# %%
df.columns

# %%
df.head()

# %%
df.shape

# %%
df.size

# %%
df.info()

# %%
df.describe()

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
(df == 0).any()

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
invalid_zero_cols = [
    'glucose',
    'bloodpressure',
    'skinthickness',
    'insulin',
    'bmi'
]

df[invalid_zero_cols] = df[invalid_zero_cols].replace(0, np.nan)

# %%
df.isnull().sum()

# %%
for col in invalid_zero_cols:
    df[col].fillna(df[col].mean(), inplace=True)

    # mediam represents: a typical patient not too high not too low not influenced bu outliers

# %%
df.isnull().sum()

# %%
x = df.drop(columns = ['outcome'])
y = df['outcome']

# %%
x.columns

# %%
y.name

# %%
# train and test split

from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(
    x,y,test_size = 0.2, random_state = 42
)

# %%
x_train.shape, x_test.shape

# %%
y.value_counts(normalize=True)

# %%
y_train.value_counts(normalize=True)

# %%
y_test.value_counts(normalize=True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()
log_reg.fit(x_train_scaled, y_train)

# %%
y_pred = log_reg.predict(x_test_scaled)

# %%
y_pred[:10]

# %%
log_reg.score(x_train_scaled,y_train)

# %%
log_reg.score(x_test_scaled, y_test)

# %%
y_prob = log_reg.predict_proba(x_test_scaled)

# %%
y_prob[:20]

# %%
y_prob_diabetic = y_prob[:,1]
y_prob_diabetic[:10]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm

# [TN FP]
# [FN TP]

# TN - true negative - actually non diabteic
# FP - false positive - actually non diabteic but predicted as diabteic
# FN - false negative - actually diabteic but predicted as non diabteic
# TP - true positive - actually diabteic

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# machine ,it finds a strong , margin based decision
# boundary that ofeten improve recall on small
# well scalled datasets

# the main reason to use is dataset is small in size,
# we did the scalling, chances are high to get better recall

# %%
from sklearn.svm import SVC

# Initialize the SVC model with a linear kernel for simplicity
svm_model = SVC(kernel='linear', probability=True)

# Train the model on the scaled training data
svm_model.fit(x_train_scaled, y_train)

# %%
y_pred_svm = svm_model.predict(x_test_scaled)

svm_model.score(x_test_scaled, y_test)

# %%
svm_accuracy_prob=svm_model.predict_proba(x_test_scaled)
svm_accuracy_prob[:10]

# %%
y_prob[:10]

# %%
from sklearn.metrics import confusion_matrix, classification_report
